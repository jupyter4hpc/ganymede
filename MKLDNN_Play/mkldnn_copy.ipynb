# %% [markdown]
# # MKLDNN CSV FILE DATA PLOTS

# %%
# !conda create -y -n jhub_data, source activate jhub_data; conda install -y numpy scipy matplotlib pandas sklearn tensorflow keras pytorch
# !source activate jhub_data; conda install -c intel daal4py
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - jhub_data
#   - activate
#   - source
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - sklearn
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
# !conda remove -y --name jhub_testenv --all

# %%
# !conda create -y -n jhub_test
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/gurunathreddybairi/anaconda3/envs/jhub_test
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate jhub_test
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source activate jhub_test; conda install -y numpy scipy matplotlib pandas h5py scikit-learn tensorflow keras pytorch
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/gurunathreddybairi/anaconda3/envs/jhub_test
#
#   added / updated specs:
#     - h5py
#     - keras
#     - matplotlib
#     - numpy
#     - pandas
#     - pytorch
#     - scikit-learn
#     - scipy
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _pytorch_select-0.1        |            cpu_0         169 KB
#     cffi-1.14.0                |   py37hc512035_1         216 KB
#     joblib-0.15.1              |             py_0         208 KB
#     keras-2.3.1                |                0          12 KB
#     keras-base-2.3.1           |           py37_0         501 KB
#     llvm-openmp-10.0.0         |       h28b9765_0         236 KB
#     ninja-1.9.0                |   py37h04f5b5a_0          90 KB
#     pycparser-2.20             |             py_0          92 KB
#     pytorch-1.4.0              |cpu_py37hf9bb1df_0        26.2 MB
#     pyyaml-5.3.1               |   py37haf1e3a3_1         165 KB
#     scikit-learn-0.23.1        |   py37h603561c_0         4.6 MB
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          17 KB
#     yaml-0.2.5                 |       haf1e3a3_0          72 KB
#     ------------------------------------------------------------
#                                            Total:        32.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _pytorch_select    pkgs/main/osx-64::_pytorch_select-0.1-cpu_0
#   _tflow_select      pkgs/main/osx-64::_tflow_select-2.3.0-mkl
#   absl-py            pkgs/main/osx-64::absl-py-0.9.0-py37_0
#   astor              pkgs/main/osx-64::astor-0.8.0-py37_0
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   c-ares             pkgs/main/osx-64::c-ares-1.15.0-h1de35cc_1001
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2020.6.24-0
#   certifi            pkgs/main/osx-64::certifi-2020.6.20-py37_0
#   cffi               pkgs/main/osx-64::cffi-1.14.0-py37hc512035_1
#   cycler             pkgs/main/osx-64::cycler-0.10.0-py37_0
#   freetype           pkgs/main/osx-64::freetype-2.10.2-ha233b18_0
#   gast               pkgs/main/osx-64::gast-0.2.2-py37_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-py_0
#   grpcio             pkgs/main/osx-64::grpcio-1.16.1-py37h044775b_1
#   h5py               pkgs/main/osx-64::h5py-2.10.0-py37h0601b69_1
#   hdf5               pkgs/main/osx-64::hdf5-1.10.6-hdbbcd12_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2019.4-233
#   joblib             pkgs/main/noarch::joblib-0.15.1-py_0
#   keras              pkgs/main/osx-64::keras-2.3.1-0
#   keras-applications pkgs/main/noarch::keras-applications-1.0.8-py_0
#   keras-base         pkgs/main/osx-64::keras-base-2.3.1-py37_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.0-py_1
#   kiwisolver         pkgs/main/osx-64::kiwisolver-1.2.0-py37h04f5b5a_0
#   libcxx             pkgs/main/osx-64::libcxx-10.0.0-1
#   libedit            pkgs/main/osx-64::libedit-3.1.20191231-haf1e3a3_0
#   libffi             pkgs/main/osx-64::libffi-3.3-hb1e8313_2
#   libgfortran        pkgs/main/osx-64::libgfortran-3.0.1-h93005f0_2
#   libpng             pkgs/main/osx-64::libpng-1.6.37-ha441bb4_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-3.12.3-hab81aa3_0
#   llvm-openmp        pkgs/main/osx-64::llvm-openmp-10.0.0-h28b9765_0
#   markdown           pkgs/main/osx-64::markdown-3.1.1-py37_0
#   matplotlib         pkgs/main/osx-64::matplotlib-3.2.2-0
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.2.2-py37h5670ca0_0
#   mkl                pkgs/main/osx-64::mkl-2019.4-233
#   mkl-service        pkgs/main/osx-64::mkl-service-2.3.0-py37hfbe908c_0
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.1.0-py37hc64f4ea_0
#   mkl_random         pkgs/main/osx-64::mkl_random-1.1.1-py37h959d312_0
#   ncurses            pkgs/main/osx-64::ncurses-6.2-h0a44026_1
#   ninja              pkgs/main/osx-64::ninja-1.9.0-py37h04f5b5a_0
#   numpy              pkgs/main/osx-64::numpy-1.18.5-py37h1da2735_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.18.5-py37h3304bdc_0
#   openssl            pkgs/main/osx-64::openssl-1.1.1g-h1de35cc_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.1.0-py_0
#   pandas             pkgs/main/osx-64::pandas-1.0.5-py37h959d312_0
#   pip                pkgs/main/osx-64::pip-20.1.1-py37_1
#   protobuf           pkgs/main/osx-64::protobuf-3.12.3-py37hb1e8313_0
#   pycparser          pkgs/main/noarch::pycparser-2.20-py_0
#   pyparsing          pkgs/main/noarch::pyparsing-2.4.7-py_0
#   python             pkgs/main/osx-64::python-3.7.7-hf48f09d_4
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   pytorch            pkgs/main/osx-64::pytorch-1.4.0-cpu_py37hf9bb1df_0
#   pytz               pkgs/main/noarch::pytz-2020.1-py_0
#   pyyaml             pkgs/main/osx-64::pyyaml-5.3.1-py37haf1e3a3_1
#   readline           pkgs/main/osx-64::readline-8.0-h1de35cc_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.23.1-py37h603561c_0
#   scipy              pkgs/main/osx-64::scipy-1.5.0-py37h912ce22_0
#   setuptools         pkgs/main/osx-64::setuptools-47.3.1-py37_0
#   six                pkgs/main/noarch::six-1.15.0-py_0
#   sqlite             pkgs/main/osx-64::sqlite-3.32.3-hffcf06c_0
#   tensorboard        pkgs/main/noarch::tensorboard-2.0.0-pyhb38c66f_1
#   tensorflow         pkgs/main/osx-64::tensorflow-2.0.0-mkl_py37hda344b4_0
#   tensorflow-base    pkgs/main/osx-64::tensorflow-base-2.0.0-mkl_py37h66b1bf0_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.0.0-pyh2649769_0
#   termcolor          pkgs/main/osx-64::termcolor-1.1.0-py37_1
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#   tk                 pkgs/main/osx-64::tk-8.6.10-hb0a8c7a_0
#   tornado            pkgs/main/osx-64::tornado-6.0.4-py37h1de35cc_1
#   werkzeug           pkgs/main/noarch::werkzeug-1.0.1-py_0
#   wheel              pkgs/main/osx-64::wheel-0.34.2-py37_0
#   wrapt              pkgs/main/osx-64::wrapt-1.12.1-py37h1de35cc_1
#   xz                 pkgs/main/osx-64::xz-5.2.5-h1de35cc_0
#   yaml               pkgs/main/osx-64::yaml-0.2.5-haf1e3a3_0
#   zlib               pkgs/main/osx-64::zlib-1.2.11-h1de35cc_3
#
#
#
# Downloading and Extracting Packages
# yaml-0.2.5           | 72 KB     | ##################################### | 100%
# keras-base-2.3.1     | 501 KB    | ##################################### | 100%
# _pytorch_select-0.1  | 169 KB    | ##################################### | 100%
# joblib-0.15.1        | 208 KB    | ##################################### | 100%
# pytorch-1.4.0        | 26.2 MB   | ##################################### | 100%
# pycparser-2.20       | 92 KB     | ##################################### | 100%
# pyyaml-5.3.1         | 165 KB    | ##################################### | 100%
# threadpoolctl-2.1.0  | 17 KB     | ##################################### | 100%
# llvm-openmp-10.0.0   | 236 KB    | ##################################### | 100%
# ninja-1.9.0          | 90 KB     | ##################################### | 100%
# keras-2.3.1          | 12 KB     | ##################################### | 100%
# cffi-1.14.0          | 216 KB    | ##################################### | 100%
# scikit-learn-0.23.1  | 4.6 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import numpy
import scipy
import matplotlib
import pandas
import sys
print('Python version: {}'.format(sys.version))
import h5py
# Out:
# Python version: 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
headers =['MKL','Stage','Primitive_kind','Primitive_name','Propogation_kind','Data_type_format','Auxiliary','Problem_description','Time(ms)']

df = pd.read_csv('log_train_hyper_xla_cache_x0_b4_n1_p1_t64_i1_m64_dfalse_nfalse_kk0__r0.001_oadam_s04_329213_.txt.csv', header= None, names=headers)

# %%
df.head()
# Out:
#               MKL Stage Primitive_kind Primitive_name Propogation_kind  \
# 0  mkldnn_verbose  exec        reorder        jit:uni            undef
# 1  mkldnn_verbose  exec        reorder        jit:uni            undef
# 2  mkldnn_verbose  exec        reorder        jit:uni            undef
# 3  mkldnn_verbose  exec        reorder        jit:uni            undef
# 4  mkldnn_verbose  exec        reorder        jit:uni            undef
#
#                  Data_type_format Auxiliary Problem_description   Time(ms)
# 0  in:f32_blocked out:f32_blocked     num:1        1x49x49x49x1  52.439900
# 1  in:f32_blocked out:f32_blocked     num:1        1x49x49x49x1   0.729004
# 2  in:f32_blocked out:f32_blocked     num:1        1x49x49x49x1   6.431880
# 3  in:f32_blocked out:f32_blocked     num:1        1x49x49x49x1   0.687012
# 4  in:f32_blocked out:f32_blocked     num:1        1x49x49x49x1   0.548828

# %%
df
# Out:
#                    MKL Stage Primitive_kind     Primitive_name  \
# 0       mkldnn_verbose  exec        reorder            jit:uni
# 1       mkldnn_verbose  exec        reorder            jit:uni
# 2       mkldnn_verbose  exec        reorder            jit:uni
# 3       mkldnn_verbose  exec        reorder            jit:uni
# 4       mkldnn_verbose  exec        reorder            jit:uni
# ...                ...   ...            ...                ...
# 134023  mkldnn_verbose  exec        eltwise  jit:avx512_common
# 134024  mkldnn_verbose  exec        reorder            jit:uni
# 134025  mkldnn_verbose  exec        reorder         simple:any
# 134026  mkldnn_verbose  exec    convolution  jit:avx512_common
# 134027  mkldnn_verbose  exec        reorder         simple:any
#
#         Propogation_kind                                   Data_type_format  \
# 0                  undef                     in:f32_blocked out:f32_blocked
# 1                  undef                     in:f32_blocked out:f32_blocked
# 2                  undef                     in:f32_blocked out:f32_blocked
# 3                  undef                     in:f32_blocked out:f32_blocked
# 4                  undef                     in:f32_blocked out:f32_blocked
# ...                  ...                                                ...
# 134023     backward_data                      fdata:nCdhw16c fdiff:nCdhw16c
# 134024             undef                      in:f32_nCdhw16c out:f32_ndhwc
# 134025             undef                      in:f32_ndhwc out:f32_nCdhw16c
# 134026  backward_weights  fsrc:nCdhw16c fwei:OIdhw16i16o fbia:undef fdst...
# 134027             undef                   in:f32_OIdhw16i16o out:f32_dhwio
#
#                      Auxiliary  \
# 0                        num:1
# 1                        num:1
# 2                        num:1
# 3                        num:1
# 4                        num:1
# ...                        ...
# 134023        alg:eltwise_relu
# 134024                   num:1
# 134025                   num:1
# 134026  alg:convolution_direct
# 134027                   num:1
#
#                                       Problem_description   Time(ms)
# 0                                            1x49x49x49x1  52.439900
# 1                                            1x49x49x49x1   0.729004
# 2                                            1x49x49x49x1   6.431880
# 3                                            1x49x49x49x1   0.687012
# 4                                            1x49x49x49x1   0.548828
# ...                                                   ...        ...
# 134023                                    mb4ic32ih33iw33   0.708008
# 134024                                      4x32x33x33x33   0.797852
# 134025                                       4x2x33x33x33   0.493164
# 134026  mb4_g1ic2oc32_id33od33kd3sd1dd0pd1_ih33oh33kh3...   1.809810
# 134027                                         32x2x3x3x3   0.237793
#
# [134028 rows x 9 columns]

# %%
df.to_csv("log_train_headers.csv")

# %%
df=df.sort_values(by='Time(ms)',ascending=False)
df.to_csv("log_train_ascendingorder_False.csv")

# %%
df.sort_values(by='Time(ms)',ascending=True)
df.to_csv("log_train_ascendingorder_True.csv")

# %%
sumdf = df.groupby(by='Primitive_kind').sum()
sumdf.plot(kind='bar',title='TF1.13, Batch=4')
plt.tight_layout()
plt.savefig('tf1.13_inference.png')

# %%
sumdf = df.groupby(by='Propogation_kind').sum()
sumdf.plot(kind='bar',title='TF1.13, Batch=4')
plt.tight_layout()
plt.savefig('tf1.13_inference.png')

# %%
sumdf = df.groupby(by='Stage').sum()
sumdf.plot(kind='bar',title='TF1.13, Batch=4')
plt.tight_layout()
plt.savefig('tf1.13_inference.png')

# %%
sumdf = df.groupby(by='Auxiliary').sum()
sumdf.plot(kind='bar',title='TF1.13, Batch=4')
plt.tight_layout()
plt.savefig('tf1.13_inference.png')

# %%
sumdf = df.groupby(by='Problem_description').sum()
sumdf.plot(kind='bar',title='TF1.13, Batch=4')
#plt.tight_layout()
plt.savefig('tf1.13_inference.png')

# %%
#countdf = df.count(axis=2)
#groupdf = df.groupby(by='Propogation_kind')
#sumdf = df.groupby(by='Stage').sum()
#sumdf = df.groupby(by='Auxiliary').sum()
#sumdf = df.groupby(by='Problem_description').sum()
#groupdf.cumcount()
#countdf.plot(kind='bar')

# %%
#countdf = df.count(axis=2)
#groupdf = df.groupby(by='Propogation_kind')
#groupdf.cumcount()
#countdf.plot(kind='bar')

# %%
countdf = df.count(axis=0)
groupdf = df.groupby(by='Propogation_kind')
groupdf.cumcount()
countdf.plot(kind='bar')

# %%
countdf = df.count(axis=1)
groupdf = df.groupby(by='Propogation_kind')
groupdf.cumcount()
countdf.plot(kind='bar')

# %%
groupkind_df = df.groupby(by='Primitive_kind')
groupkind_df.plot()
# Out:
# Primitive_kind
# convolution    AxesSubplot(0.125,0.125;0.775x0.755)
# eltwise        AxesSubplot(0.125,0.125;0.775x0.755)
# reorder        AxesSubplot(0.125,0.125;0.775x0.755)
# sum            AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
groupkind_df = df.groupby(by='Propogation_kind')
groupkind_df.plot()
# Out:
# Propogation_kind
# backward_data       AxesSubplot(0.125,0.125;0.775x0.755)
# backward_weights    AxesSubplot(0.125,0.125;0.775x0.755)
# forward_training    AxesSubplot(0.125,0.125;0.775x0.755)
# undef               AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
groupkind_df = df.groupby(by='Stage')
groupkind_df.plot()
# Out:
# Stage
# exec    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
groupkind_df = df.groupby(by='Auxiliary')
groupkind_df.plot()
# Out:
# Auxiliary
# alg:convolution_direct    AxesSubplot(0.125,0.125;0.775x0.755)
# alg:eltwise_relu          AxesSubplot(0.125,0.125;0.775x0.755)
# num:1                     AxesSubplot(0.125,0.125;0.775x0.755)
# num:2                     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
groupkind_df = df.groupby(by='Problem_description')
groupkind_df.plot()
# Out:
# Problem_description
# 1x32x1x1x1                                                                       AxesSubplot(0.125,0.125;0.775x0.755)
# 1x49x49x49x1                                                                     AxesSubplot(0.125,0.125;0.775x0.755)
# 32x2x3x3x3                                                                       AxesSubplot(0.125,0.125;0.775x0.755)
# 32x32x3x3x3                                                                      AxesSubplot(0.125,0.125;0.775x0.755)
# 4x1x33x33x33                                                                     AxesSubplot(0.125,0.125;0.775x0.755)
# 4x2x33x33x33                                                                     AxesSubplot(0.125,0.125;0.775x0.755)
# 4x32x33x33x33                                                                    AxesSubplot(0.125,0.125;0.775x0.755)
# mb4_g1ic2oc32_id33od33kd3sd1dd0pd1_ih33oh33kh3sh1dh0ph1_iw33ow33kw3sw1dw0pw1     AxesSubplot(0.125,0.125;0.775x0.755)
# mb4_g1ic32oc1_id33od33kd1sd1dd0pd0_ih33oh33kh1sh1dh0ph0_iw33ow33kw1sw1dw0pw0     AxesSubplot(0.125,0.125;0.775x0.755)
# mb4_g1ic32oc32_id33od33kd3sd1dd0pd1_ih33oh33kh3sh1dh0ph1_iw33ow33kw3sw1dw0pw1    AxesSubplot(0.125,0.125;0.775x0.755)
# mb4ic32ih33iw33                                                                  AxesSubplot(0.125,0.125;0.775x0.755)
# mb4ic33ih33iw32                                                                  AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
line = ''

def prune_mkldnn_verbose(logfile):
    key = 'mkldnn_verbose,'
    csvlines = []
    prunedlines = []
    with open(logfile,'r') as f:
        lines = f.readlines()
    for line in lines:
        if line.startswith(key):
            csvlines.append(line)
        else:
            prunedlines.append(line)
